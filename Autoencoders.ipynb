# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Feb  1 16:35:38 2023

@author: User
"""


import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, Conv2DTranspose
from keras.constraints import max_norm
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np

# Model configuration
img_width, img_height = 28, 28
batch_size = 150
no_epochs = 50
validation_split = 0.2
verbosity = 1
max_norm_value = 2.0
noise_factor = 0.55
number_of_visualizations = 6

# Load MNIST dataset
(input_train, target_train), (input_test, target_test) = mnist.load_data()

# Reshape data based on channels first / channels last strategy.
# This is dependent on whether you use TF, Theano or CNTK as backend.
# Source: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py
if K.image_data_format() == 'channels_first':
    input_train = input_train.reshape(input_train.shape[0], 1, img_width, img_height)
    input_test = input_test.reshape(input_test.shape[0], 1, img_width, img_height)
    input_shape = (1, img_width, img_height)
else:
    input_train = input_train.reshape(input_train.shape[0], img_width, img_height, 1)
    input_test = input_test.reshape(input_test.shape[0], img_width, img_height, 1)
    input_shape = (img_width, img_height, 1)

# Parse numbers as floats
input_train = input_train.astype('float32')
input_test = input_test.astype('float32')

# Normalize data
input_train = input_train / 255
input_test = input_test / 255

# Add noise
pure = input_train
pure_test = input_test
noise = np.random.normal(0, 1, pure.shape)
noise_test = np.random.normal(0, 1, pure_test.shape)
noisy_input = pure + noise_factor * noise
noisy_input_test = pure_test + noise_factor * noise_test

# Create the model
model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Conv2DTranspose(32, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Conv2DTranspose(64, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(Conv2D(1, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='sigmoid', padding='same'))

model.summary()
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model.png')

# Compile and fit data
model.compile(optimizer='adam', loss='binary_crossentropy')
model.fit(noisy_input, pure,
                epochs=no_epochs,
                batch_size=batch_size,
                validation_split=validation_split)

# Generate denoised images
samples = noisy_input_test[:number_of_visualizations]
targets = target_test[:number_of_visualizations]
denoised_images = model.predict(samples)

# Plot denoised images
for i in range(0, number_of_visualizations):
  # Get the sample and the reconstruction
  noisy_image = noisy_input_test[i][:, :, 0]
  pure_image  = pure_test[i][:, :, 0]
  denoised_image = denoised_images[i][:, :, 0]
  input_class = targets[i]
  # Matplotlib preparations
  fig, axes = plt.subplots(1, 3)
  fig.set_size_inches(8, 3.5)
  # Plot sample and reconstruciton
  axes[0].imshow(noisy_image)
  axes[0].set_title('Noisy image')
  axes[1].imshow(pure_image)
  axes[1].set_title('Pure image')
  axes[2].imshow(denoised_image)
  axes[2].set_title('Denoised image')
  fig.suptitle(f'MNIST target = {input_class}')
  plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        18464
#
#  conv2d_transpose (Conv2DTr  (None, 26, 26, 32)        9248
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 64)        18496
#  Transpose)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         577
#
# =================================================================
# Total params: 47425 (185.25 KB)
# Trainable params: 47425 (185.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 320/320 [==============================] - 17s 18ms/step - loss: 0.1315 - val_loss: 0.1088
# Epoch 2/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.1056 - val_loss: 0.1042
# Epoch 3/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.1030 - val_loss: 0.1025
# Epoch 4/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.1016 - val_loss: 0.1018
# Epoch 5/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.1007 - val_loss: 0.1008
# Epoch 6/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.1000 - val_loss: 0.1002
# Epoch 7/50
# 320/320 [==============================] - 6s 18ms/step - loss: 0.0996 - val_loss: 0.1001
# Epoch 8/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0992 - val_loss: 0.0996
# Epoch 9/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0988 - val_loss: 0.0990
# Epoch 10/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0985 - val_loss: 0.0989
# Epoch 11/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0982 - val_loss: 0.0986
# Epoch 12/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0980 - val_loss: 0.0987
# Epoch 13/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0978 - val_loss: 0.0983
# Epoch 14/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0976 - val_loss: 0.0983
# Epoch 15/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0975 - val_loss: 0.0986
# Epoch 16/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0973 - val_loss: 0.0982
# Epoch 17/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0972 - val_loss: 0.0978
# Epoch 18/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0971 - val_loss: 0.0975
# Epoch 19/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0969 - val_loss: 0.0975
# Epoch 20/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0968 - val_loss: 0.0976
# Epoch 21/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0968 - val_loss: 0.0974
# Epoch 22/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0966 - val_loss: 0.0972
# Epoch 23/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0966 - val_loss: 0.0974
# Epoch 24/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0965 - val_loss: 0.0972
# Epoch 25/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0964 - val_loss: 0.0972
# Epoch 26/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0964 - val_loss: 0.0971
# Epoch 27/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0962 - val_loss: 0.0973
# Epoch 28/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0962 - val_loss: 0.0971
# Epoch 29/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0961 - val_loss: 0.0973
# Epoch 30/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0961 - val_loss: 0.0970
# Epoch 31/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0960 - val_loss: 0.0970
# Epoch 32/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0960 - val_loss: 0.0970
# Epoch 33/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0959 - val_loss: 0.0970
# Epoch 34/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0959 - val_loss: 0.0968
# Epoch 35/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0959 - val_loss: 0.0969
# Epoch 36/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0958 - val_loss: 0.0969
# Epoch 37/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0958 - val_loss: 0.0967
# Epoch 38/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0958 - val_loss: 0.0968
# Epoch 39/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0957 - val_loss: 0.0968
# Epoch 40/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 41/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 42/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0957 - val_loss: 0.0967
# Epoch 43/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0956 - val_loss: 0.0967
# Epoch 44/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0956 - val_loss: 0.0967
# Epoch 45/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0955 - val_loss: 0.0967
# Epoch 46/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 47/50
# 320/320 [==============================] - 5s 16ms/step - loss: 0.0955 - val_loss: 0.0968
# Epoch 48/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 49/50
# 320/320 [==============================] - 6s 17ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 50/50
# 320/320 [==============================] - 5s 17ms/step - loss: 0.0955 - val_loss: 0.0967
# 1/1 [==============================] - 0s 219ms/step

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Feb  1 16:35:38 2023

@author: User
"""


import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, Conv2DTranspose, BatchNormalization
from keras.constraints import max_norm

from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np

# Model configuration
img_width, img_height = 28, 28
batch_size = 150
no_epochs = 100
validation_split = 0.2
verbosity = 1
max_norm_value = 2.0
noise_factor = 0.55
number_of_visualizations = 6

# Load MNIST dataset
(input_train, target_train), (input_test, target_test) = mnist.load_data()

# Reshape data based on channels first / channels last strategy.
# This is dependent on whether you use TF, Theano or CNTK as backend.
# Source: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py
if K.image_data_format() == 'channels_first':
    input_train = input_train.reshape(input_train.shape[0], 1, img_width, img_height)
    input_test = input_test.reshape(input_test.shape[0], 1, img_width, img_height)
    input_shape = (1, img_width, img_height)
else:
    input_train = input_train.reshape(input_train.shape[0], img_width, img_height, 1)
    input_test = input_test.reshape(input_test.shape[0], img_width, img_height, 1)
    input_shape = (img_width, img_height, 1)

# Parse numbers as floats
input_train = input_train.astype('float32')
input_test = input_test.astype('float32')

# Normalize data
input_train = input_train / 255
input_test = input_test / 255

# Add noise
pure = input_train
pure_test = input_test
noise = np.random.normal(0, 1, pure.shape)
noise_test = np.random.normal(0, 1, pure_test.shape)
noisy_input = pure + noise_factor * noise
noisy_input_test = pure_test + noise_factor * noise_test

# Create the model
model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform', input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(32, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2DTranspose(64, kernel_size=(3,3), kernel_constraint=max_norm(max_norm_value), activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2D(1, kernel_size=(3, 3), kernel_constraint=max_norm(max_norm_value), activation='sigmoid', padding='same'))



# Transpose layer decode the image



model.summary()
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model.png')

# Compile and fit data
optimizer = keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='binary_crossentropy')
model.fit(noisy_input, pure,
                epochs=no_epochs,
                batch_size=batch_size,
                validation_split=validation_split)

# Generate denoised images
samples = noisy_input_test[:number_of_visualizations]
targets = target_test[:number_of_visualizations]
denoised_images = model.predict(samples)

# Plot denoised images
for i in range(0, number_of_visualizations):
  # Get the sample and the reconstruction
  noisy_image = noisy_input_test[i][:, :, 0]
  pure_image  = pure_test[i][:, :, 0]
  denoised_image = denoised_images[i][:, :, 0]
  input_class = targets[i]
  # Matplotlib preparations
  fig, axes = plt.subplots(1, 3)
  fig.set_size_inches(8, 3.5)
  # Plot sample and reconstruciton
  axes[0].imshow(noisy_image)
  axes[0].set_title('Noisy image')
  axes[1].imshow(pure_image)
  axes[1].set_title('Pure image')
  axes[2].imshow(denoised_image)
  axes[2].set_title('Denoised image')
  fig.suptitle(f'MNIST target = {input_class}')
  plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (Batch  (None, 26, 26, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        18464
#
#  batch_normalization_1 (Bat  (None, 24, 24, 32)        128
#  chNormalization)
#
#  conv2d_transpose (Conv2DTr  (None, 26, 26, 32)        9248
#  anspose)
#
#  batch_normalization_2 (Bat  (None, 26, 26, 32)        128
#  chNormalization)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 64)        18496
#  Transpose)
#
#  batch_normalization_3 (Bat  (None, 28, 28, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         577
#
# =================================================================
# Total params: 48193 (188.25 KB)
# Trainable params: 47809 (186.75 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 320/320 [==============================] - 28s 46ms/step - loss: 0.1600 - val_loss: 0.1063
# Epoch 2/100
# 320/320 [==============================] - 11s 35ms/step - loss: 0.1029 - val_loss: 0.1025
# Epoch 3/100
# 320/320 [==============================] - 12s 36ms/step - loss: 0.1010 - val_loss: 0.1008
# Epoch 4/100
# 320/320 [==============================] - 15s 46ms/step - loss: 0.1000 - val_loss: 0.0999
# Epoch 5/100
# 320/320 [==============================] - 12s 37ms/step - loss: 0.0995 - val_loss: 0.0994
# Epoch 6/100
# 320/320 [==============================] - 16s 51ms/step - loss: 0.0991 - val_loss: 0.1002
# Epoch 7/100
# 320/320 [==============================] - 14s 44ms/step - loss: 0.0985 - val_loss: 0.0998
# Epoch 8/100
# 320/320 [==============================] - 17s 52ms/step - loss: 0.0984 - val_loss: 0.0995
# Epoch 9/100
# 320/320 [==============================] - 12s 37ms/step - loss: 0.0981 - val_loss: 0.0984
# Epoch 10/100
# 320/320 [==============================] - 13s 42ms/step - loss: 0.0979 - val_loss: 0.0981
# Epoch 11/100
# 320/320 [==============================] - 15s 48ms/step - loss: 0.0978 - val_loss: 0.0985
# Epoch 12/100
# 320/320 [==============================] - 15s 49ms/step - loss: 0.0975 - val_loss: 0.1004
# Epoch 13/100
# 320/320 [==============================] - 14s 45ms/step - loss: 0.0974 - val_loss: 0.0982
# Epoch 14/100
# 320/320 [==============================] - 12s 37ms/step - loss: 0.0973 - val_loss: 0.0976
# Epoch 15/100
# 320/320 [==============================] - 15s 46ms/step - loss: 0.0972 - val_loss: 0.0976
# Epoch 16/100
# 320/320 [==============================] - 15s 46ms/step - loss: 0.0970 - val_loss: 0.0979
# Epoch 17/100
# 320/320 [==============================] - 15s 48ms/step - loss: 0.0970 - val_loss: 0.0977
# Epoch 18/100
# 320/320 [==============================] - 15s 47ms/step - loss: 0.0969 - val_loss: 0.0976
# Epoch 19/100
# 320/320 [==============================] - 17s 52ms/step - loss: 0.0969 - val_loss: 0.0986
# Epoch 20/100
# 320/320 [==============================] - 15s 47ms/step - loss: 0.0968 - val_loss: 0.0973
# Epoch 21/100
# 320/320 [==============================] - 14s 43ms/step - loss: 0.0966 - val_loss: 0.0975
# Epoch 22/100
# 320/320 [==============================] - 16s 49ms/step - loss: 0.0966 - val_loss: 0.0970
# Epoch 23/100
# 320/320 [==============================] - 13s 41ms/step - loss: 0.0965 - val_loss: 0.0974
# Epoch 24/100
# 320/320 [==============================] - 16s 51ms/step - loss: 0.0965 - val_loss: 0.0971
# Epoch 25/100
# 320/320 [==============================] - 13s 42ms/step - loss: 0.0964 - val_loss: 0.0973
# Epoch 26/100
# 320/320 [==============================] - 15s 48ms/step - loss: 0.0964 - val_loss: 0.0971
# Epoch 27/100
# 320/320 [==============================] - 14s 43ms/step - loss: 0.0963 - val_loss: 0.0971
# Epoch 28/100
# 320/320 [==============================] - 14s 43ms/step - loss: 0.0962 - val_loss: 0.0973
# Epoch 29/100
# 320/320 [==============================] - 15s 46ms/step - loss: 0.0963 - val_loss: 0.0977
# Epoch 30/100
# 320/320 [==============================] - 15s 48ms/step - loss: 0.0962 - val_loss: 0.0969
# Epoch 31/100
# 320/320 [==============================] - 13s 40ms/step - loss: 0.0962 - val_loss: 0.0970
# Epoch 32/100
# 320/320 [==============================] - 16s 50ms/step - loss: 0.0961 - val_loss: 0.0967
# Epoch 33/100
# 320/320 [==============================] - 16s 51ms/step - loss: 0.0961 - val_loss: 0.0969
# Epoch 34/100
# 320/320 [==============================] - 14s 43ms/step - loss: 0.0960 - val_loss: 0.0967
# Epoch 35/100
# 320/320 [==============================] - 16s 49ms/step - loss: 0.0959 - val_loss: 0.0968
# Epoch 36/100
# 320/320 [==============================] - 13s 41ms/step - loss: 0.0960 - val_loss: 0.0970
# Epoch 37/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0959 - val_loss: 0.0981
# Epoch 38/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0958 - val_loss: 0.0967
# Epoch 39/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0958 - val_loss: 0.0975
# Epoch 40/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0958 - val_loss: 0.0973
# Epoch 41/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 42/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0957 - val_loss: 0.0971
# Epoch 43/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0957 - val_loss: 0.0967
# Epoch 44/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 45/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0957 - val_loss: 0.0967
# Epoch 46/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0957 - val_loss: 0.0969
# Epoch 47/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0956 - val_loss: 0.0967
# Epoch 48/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0956 - val_loss: 0.0968
# Epoch 49/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - val_loss: 0.0978
# Epoch 50/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0956 - val_loss: 0.0969
# Epoch 51/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - val_loss: 0.0965
# Epoch 52/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 53/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - val_loss: 0.0967
# Epoch 54/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - val_loss: 0.0971
# Epoch 55/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - val_loss: 0.0966
# Epoch 56/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0955 - val_loss: 0.0967
# Epoch 57/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0954 - val_loss: 0.0967
# Epoch 58/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0954 - val_loss: 0.0967
# Epoch 59/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0954 - val_loss: 0.0965
# Epoch 60/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0953 - val_loss: 0.0965
# Epoch 61/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0953 - val_loss: 0.0966
# Epoch 62/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0953 - val_loss: 0.0964
# Epoch 63/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0953 - val_loss: 0.0967
# Epoch 64/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0953 - val_loss: 0.0967
# Epoch 65/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0953 - val_loss: 0.0971
# Epoch 66/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0952 - val_loss: 0.0964
# Epoch 67/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0952 - val_loss: 0.0965
# Epoch 68/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0952 - val_loss: 0.0964
# Epoch 69/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0951 - val_loss: 0.0963
# Epoch 70/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0952 - val_loss: 0.0966
# Epoch 71/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0951 - val_loss: 0.0964
# Epoch 72/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0952 - val_loss: 0.0966
# Epoch 73/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0952 - val_loss: 0.0964
# Epoch 74/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0951 - val_loss: 0.0964
# Epoch 75/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0951 - val_loss: 0.0964
# Epoch 76/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0951 - val_loss: 0.0964
# Epoch 77/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0964
# Epoch 78/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0950 - val_loss: 0.0963
# Epoch 79/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0964
# Epoch 80/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0950 - val_loss: 0.0963
# Epoch 81/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0966
# Epoch 82/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0950 - val_loss: 0.0966
# Epoch 83/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0966
# Epoch 84/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0969
# Epoch 85/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0950 - val_loss: 0.0965
# Epoch 86/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0964
# Epoch 87/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0965
# Epoch 88/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0964
# Epoch 89/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0949 - val_loss: 0.0963
# Epoch 90/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0963
# Epoch 91/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0949 - val_loss: 0.0964
# Epoch 92/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0964
# Epoch 93/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0949 - val_loss: 0.0966
# Epoch 94/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0950 - val_loss: 0.0965
# Epoch 95/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0948 - val_loss: 0.0963
# Epoch 96/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0968
# Epoch 97/100
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0949 - val_loss: 0.0971
# Epoch 98/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0949 - val_loss: 0.0965
# Epoch 99/100
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0949 - val_loss: 0.0965
# Epoch 100/100
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0948 - val_loss: 0.0964
# 1/1 [==============================] - 0s 230ms/step
